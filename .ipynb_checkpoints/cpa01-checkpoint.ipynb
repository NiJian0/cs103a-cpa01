# %% [markdown]
# # Analysis of historical stock prices (last 5 years) for all companies currently found on the S&P 500 index.
# The data comes from kaggle and the site for this particular data is [https://www.kaggle.com/datasets/camnugent/sandp500].
# I've downloaded the data and stored it in all_stocks_5yr.csv

# %% [markdown]
# Some questions I try to answer
#
# how is the stock closing price of AAPL changed over years
# what information we can get from the closing price of stock 'AAPL', 'MSFT' and 'GOOGL' changing over years
# what is the candlestick chart of AAPL

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.graph_objects as go
import mplfinance as fplt

# %%
df = pd.read_csv('all_stocks_5yr.csv')
df
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
df.describe()
# Out:
#                 open           high            low          close  \
# count  619029.000000  619032.000000  619032.000000  619040.000000
# mean       83.023334      83.778311      82.256096      83.043763
# std        97.378769      98.207519      96.507421      97.389748
# min         1.620000       1.690000       1.500000       1.590000
# 25%        40.220000      40.620000      39.830000      40.245000
# 50%        62.590000      63.150000      62.020000      62.620000
# 75%        94.370000      95.180000      93.540000      94.410000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  6.190400e+05
# mean   4.321823e+06
# std    8.693610e+06
# min    0.000000e+00
# 25%    1.070320e+06
# 50%    2.082094e+06
# 75%    4.284509e+06
# max    6.182376e+08

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
df[:1260].plot(figsize=(15,10))
plt.grid()
plt.title('the stock information of AAL',fontsize=16)
# Out:
# Text(0.5, 1.0, 'the stock information of AAL')

# %% [markdown]
# # Create a pivot table
#
# index is the date, and columns are the values in the Name column the value is the closing price. We can then plot just the columns we want!

# %%
df1 = pd.pivot_table(df, values='close', index=["date"], columns=["Name"])
df1
# Out:
# Name            A    AAL     AAP      AAPL    ABBV    ABC    ABT     ACN  \
# date
# 2013-02-08  45.08  14.75   78.90   67.8542   36.25  46.89  34.41   73.31
# 2013-02-11  44.60  14.46   78.39   68.5614   35.85  46.76  34.26   73.07
# 2013-02-12  44.62  14.27   78.60   66.8428   35.42  46.96  34.30   73.37
# 2013-02-13  44.75  14.66   78.97   66.7156   35.27  46.64  34.46   73.56
# 2013-02-14  44.58  13.99   78.84   66.6556   36.57  46.77  34.70   73.13
# ...           ...    ...     ...       ...     ...    ...    ...     ...
# 2018-02-01  72.83  53.88  117.29  167.7800  116.34  99.29  62.18  160.46
# 2018-02-02  71.25  52.10  113.93  160.5000  115.17  96.02  61.69  156.90
# 2018-02-05  68.22  49.76  109.86  156.4900  109.51  91.90  58.73  151.83
# 2018-02-06  68.45  51.18  112.20  163.0300  111.20  91.54  58.86  154.69
# 2018-02-07  68.06  51.40  109.93  159.5400  113.62  94.22  58.67  155.15
#
# Name          ADBE    ADI  ...     XL   XLNX    XOM   XRAY    XRX    XYL  \
# ...

# %%
df1['AAPL'].plot(figsize=(15,10))
plt.grid()
plt.title('the closing price of AAPL',fontsize=16)
# Out:
# Text(0.5, 1.0, 'the closing price of AAPL')

# %% [markdown]
# # Calculate the total volumes for all stocks
# We can use the groupby method to determine sum up the volumes of all stocks so far and show the top 20

# %%
df2 = df.groupby('Name')['volume'].agg(np.sum).sort_values(ascending=False).head(20)
df2
# Out:
# Name
# BAC      117884953591
# AAPL      68046305767
# GE        53023644686
# F         43388129992
# FB        43258314899
# MSFT      42641653597
# AMD       40941468586
# MU        38082749687
# INTC      36922332801
# CSCO      36075826186
# PFE       35527608853
# T         31850598073
# CHK       31421758366
# CMCSA     30630585625
# FCX       29648463667
# C         26044628798
# WFC       23305954532
# JPM       20885592857
# RF        20645650500
# NFLX      20405882026
# Name: volume, dtype: int64

# %%
df1[['AAPL', 'MSFT', 'GOOGL']].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %%
df.index = pd.DatetimeIndex(df['date'])
df3 = df[df['Name']=='AAPL']
fplt.plot(
            df3,
            type='candle',
            style='charles',
            title='Apple, March - 2020',
            ylabel='Price ($)',
            )
# Out:
# /Users/jianni/opt/miniconda3/lib/python3.9/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %% [markdown]
# # Answer to Questions

# %% [markdown]
# 1. The closing price of AAPL increased from 60 dollars to 130 dollars from 2013 to 2015, and then decreased 30 dollars in 2016, and rapidly increased from 100 dollars to 180 dollars before 2018.

# %% [markdown]
# 2. The stock price of GOOGL is much higher than MSFT and AAPL, but the increased rate of AAPL and MSFT is biger than GOOL. Besides, the violation of AAPL is greater then the other two stocks, in which stock MSFT increased more steadily.
